# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

ibd = pd.read_csv("plink.genome", sep='\s+')
ibd
# Out:
#         FID1       IID1  FID2       IID2  RT  EZ      Z0      Z1      Z2  \
# 0          0  HGDP00448     0  HGDP00479  OT   0  0.8538  0.0370  0.1093
# 1          0  HGDP00448     0  HGDP00985  OT   0  0.8534  0.0305  0.1161
# 2          0  HGDP00448     0  HGDP01094  OT   0  0.8454  0.0455  0.1090
# 3          0  HGDP00448     0  HGDP00982  OT   0  1.0000  0.0000  0.0000
# 4          0  HGDP00448     0  HGDP00911  OT   0  1.0000  0.0000  0.0000
# ...      ...        ...   ...        ...  ..  ..     ...     ...     ...
# 543398     0  HGDP01070     0  HGDP00671  OT   0  0.9130  0.0084  0.0786
# 543399     0  HGDP01070     0  HGDP01024  OT   0  1.0000  0.0000  0.0000
# 543400     0  HGDP01376     0  HGDP00671  OT   0  1.0000  0.0000  0.0000
# 543401     0  HGDP01376     0  HGDP01024  OT   0  1.0000  0.0000  0.0000
# 543402     0  HGDP00671     0  HGDP01024  OT   0  1.0000  0.0000  0.0000
#
#         PI_HAT  PHE       DST     PPC   RATIO
# ...

# %%
related = ibd.query("PI_HAT > 0")
related
# Out:
#         FID1       IID1  FID2       IID2  RT  EZ      Z0      Z1      Z2  \
# 0          0  HGDP00448     0  HGDP00479  OT   0  0.8538  0.0370  0.1093
# 1          0  HGDP00448     0  HGDP00985  OT   0  0.8534  0.0305  0.1161
# 2          0  HGDP00448     0  HGDP01094  OT   0  0.8454  0.0455  0.1090
# 7          0  HGDP00448     0  HGDP00461  OT   0  0.4139  0.4648  0.1213
# 8          0  HGDP00448     0  HGDP00451  OT   0  0.8532  0.0345  0.1124
# ...      ...        ...   ...        ...  ..  ..     ...     ...     ...
# 543366     0  HGDP01342     0  HGDP01024  OT   0  0.8480  0.0000  0.1520
# 543381     0  HGDP01319     0  HGDP01024  OT   0  0.8485  0.0000  0.1515
# 543385     0  HGDP01357     0  HGDP01376  OT   0  0.9267  0.0109  0.0624
# 543396     0  HGDP00953     0  HGDP01024  OT   0  0.9042  0.0000  0.0958
# 543398     0  HGDP01070     0  HGDP00671  OT   0  0.9130  0.0084  0.0786
#
#         PI_HAT  PHE       DST     PPC   RATIO
# ...

# %%
sns.histplot(data=related, x='PI_HAT', bins=13)
# Out:
# <AxesSubplot:xlabel='PI_HAT', ylabel='Count'>

# %%
sns.histplot(data=related, x='EZ', bins=13)
# Out:
# <AxesSubplot:xlabel='EZ', ylabel='Count'>

# %%
inds = np.random.choice(pops["ID"], 20)

# %%
for idd in inds:
    plt.clf()
    plt.close()
    get_ibs(idd)
    plt.savefig(f"{idd}.jpeg")
# Out:
# /tmp/ipykernel_15597/530937900.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
plt.hist(relatedness["PI_HAT"])
# Out:
# (array([5.13308e+05, 1.92270e+04, 8.77400e+03, 1.34500e+03, 2.54000e+02,
#         2.23000e+02, 1.21000e+02, 6.80000e+01, 4.30000e+01, 4.00000e+01]),
#  array([0.     , 0.07298, 0.14596, 0.21894, 0.29192, 0.3649 , 0.43788,
#         0.51086, 0.58384, 0.65682, 0.7298 ]),
#  <BarContainer object of 10 artists>)

# %%
import pandas as pd
import numpy as np

reduced = pd.read_csv("/home/shussain/popviz/results/PHATE/run2/PHATE_out.csv")
pops = pd.read_csv("/home/shussain/popviz/genomic_data/pops.csv")
relatedness = pd.read_csv("plink.genome", sep="\s+")

def get_ibs(source):
    daddy = source
    ind_daddy = pops.query(f"ID == '{daddy}'").index[0]
    contains_daddy = np.logical_or((relatedness["IID1"] == daddy), (relatedness["IID2"] == daddy))
    relatedness_to_daddy = relatedness[contains_daddy]
    relatedness_to_daddy
    
    other = [ind["IID1"] if ind["IID1"] != daddy else ind["IID2"] for i, ind in relatedness_to_daddy.iterrows()]
    relatedness_to_daddy["ID"] = other
    
    reduced["ID"] = pops["ID"]
    df = relatedness_to_daddy.set_index("ID").join(reduced.set_index("ID"))
    
    
    fig, ax = plt.subplots(1, 1, figsize=(10, 10))
    p = plt.scatter(x=df["PHATE1"], y=df["PHATE2"], c=np.log(df["PI_HAT"]), cmap="Blues")
    plt.scatter(reduced.iloc[ind_daddy, 0], reduced.iloc[ind_daddy, 1], c="red")
    plt.colorbar(p)

get_ibs("HGDP01248")
# Out:
# /tmp/ipykernel_15597/530937900.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/shussain/miniconda3/envs/popviz/lib/python3.9/site-packages/pandas/core/arraylike.py:364: RuntimeWarning:
#
# divide by zero encountered in log

# %%
df
# Out:
#            FID1       IID1  FID2       IID2  RT  EZ   Z0   Z1   Z2  PI_HAT  \
# ID
# HGDP00001     0  HGDP00001     0  HGDP01248  OT   0  1.0  0.0  0.0     0.0
# HGDP00003     0  HGDP01248     0  HGDP00003  OT   0  1.0  0.0  0.0     0.0
# HGDP00005     0  HGDP00005     0  HGDP01248  OT   0  1.0  0.0  0.0     0.0
# HGDP00007     0  HGDP00007     0  HGDP01248  OT   0  1.0  0.0  0.0     0.0
# HGDP00009     0  HGDP00009     0  HGDP01248  OT   0  1.0  0.0  0.0     0.0
# ...         ...        ...   ...        ...  ..  ..  ...  ...  ...     ...
# HGDP01415     0  HGDP01415     0  HGDP01248  OT   0  1.0  0.0  0.0     0.0
# HGDP01416     0  HGDP01416     0  HGDP01248  OT   0  1.0  0.0  0.0     0.0
# HGDP01417     0  HGDP01248     0  HGDP01417  OT   0  1.0  0.0  0.0     0.0
# HGDP01418     0  HGDP01418     0  HGDP01248  OT   0  1.0  0.0  0.0     0.0
# HGDP01419     0  HGDP01248     0  HGDP01419  OT   0  1.0  0.0  0.0     0.0
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
titanic = sns.load_dataset("titanic")
g = titanic.groupby('pclass')
survival_rates = g['survived'].mean()
n = g.size()

plot = plt.scatter(n.index, n, c=survival_rates, cmap='Reds')
plt.clf()
plt.colorbar(plot)
ax = sns.barplot(x=n.index, y=n, hue=survival_rates, palette='Reds', dodge=False)
ax.set_ylabel('n passengers')
ax.legend_.remove()
# Out:
# /tmp/ipykernel_15597/3216043179.py:10: MatplotlibDeprecationWarning:
#
# Starting from Matplotlib 3.6, colorbar() will steal space from the mappable's axes, rather than from the current axes, to place the colorbar.  To silence this warning, explicitly pass the 'ax' argument to colorbar().

# %%
survival_rates
# Out:
# pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: survived, dtype: float64

# %%
pops
# Out:
#              ID Sex     population             geographic_origin  \
# 0     HGDP00448   M  Biaka_Pygmies      Central_African_Republic
# 1     HGDP00479   M  Biaka_Pygmies      Central_African_Republic
# 2     HGDP00985   M  Biaka_Pygmies      Central_African_Republic
# 3     HGDP01094   M  Biaka_Pygmies      Central_African_Republic
# 4     HGDP00982   M  Mbuti_Pygmies  Democratic_Republic_of_Congo
# ...         ...  ..            ...                           ...
# 1038  HGDP00953   M          Yakut                       Siberia
# 1039  HGDP01070   F      Sardinian                         Italy
# 1040  HGDP01376   M  French_Basque                        France
# 1041  HGDP00671   M      Sardinian                         Italy
# 1042  HGDP01024   F            Han                         China
#
#                   region pop_group
# 0     Subsaharian_Africa    Africa
# 1     Subsaharian_Africa    Africa
# 2     Subsaharian_Africa    Africa
# 3     Subsaharian_Africa    Africa
# ...

# %%
pops.iloc[408, :]
# Out:
# ID                   HGDP01248
# Sex                          M
# population                Xibo
# geographic_origin        China
# region                    Asia
# pop_group             Est_Asia
# Name: 408, dtype: object

# %%
import numpy as np
# Out:
#         FID1       IID1  FID2       IID2  RT  EZ      Z0   Z1      Z2  PI_HAT  \
# 407        0  HGDP00448     0  HGDP01248  OT   0  1.0000  0.0  0.0000  0.0000
# 1448       0  HGDP00479     0  HGDP01248  OT   0  1.0000  0.0  0.0000  0.0000
# 2488       0  HGDP00985     0  HGDP01248  OT   0  1.0000  0.0  0.0000  0.0000
# 3527       0  HGDP01094     0  HGDP01248  OT   0  1.0000  0.0  0.0000  0.0000
# 4565       0  HGDP00982     0  HGDP01248  OT   0  1.0000  0.0  0.0000  0.0000
# ...      ...        ...   ...        ...  ..  ..     ...  ...     ...     ...
# 342737     0  HGDP01248     0  HGDP00953  OT   0  0.9185  0.0  0.0815  0.0815
# 342738     0  HGDP01248     0  HGDP01070  OT   0  1.0000  0.0  0.0000  0.0000
# 342739     0  HGDP01248     0  HGDP01376  OT   0  1.0000  0.0  0.0000  0.0000
# 342740     0  HGDP01248     0  HGDP00671  OT   0  1.0000  0.0  0.0000  0.0000
# 342741     0  HGDP01248     0  HGDP01024  OT   0  0.8632  0.0  0.1368  0.1368
#
# ...

# %%
import matplotlib.pyplot as plt

plt.hist(relatedness_to_daddy["PI_HAT"])
# Out:
# (array([794.,   0.,   0.,   0.,   4.,  10.,   4.,   8.,  73., 149.]),
#  array([0.     , 0.01412, 0.02824, 0.04236, 0.05648, 0.0706 , 0.08472,
#         0.09884, 0.11296, 0.12708, 0.1412 ]),
#  <BarContainer object of 10 artists>)

# %%
# Out:
# /tmp/ipykernel_15597/86170362.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
relatedness_to_daddy
# Out:
#         FID1       IID1  FID2       IID2  RT  EZ      Z0   Z1      Z2  PI_HAT  \
# 407        0  HGDP00448     0  HGDP01248  OT   0  1.0000  0.0  0.0000  0.0000
# 1448       0  HGDP00479     0  HGDP01248  OT   0  1.0000  0.0  0.0000  0.0000
# 2488       0  HGDP00985     0  HGDP01248  OT   0  1.0000  0.0  0.0000  0.0000
# 3527       0  HGDP01094     0  HGDP01248  OT   0  1.0000  0.0  0.0000  0.0000
# 4565       0  HGDP00982     0  HGDP01248  OT   0  1.0000  0.0  0.0000  0.0000
# ...      ...        ...   ...        ...  ..  ..     ...  ...     ...     ...
# 342737     0  HGDP01248     0  HGDP00953  OT   0  0.9185  0.0  0.0815  0.0815
# 342738     0  HGDP01248     0  HGDP01070  OT   0  1.0000  0.0  0.0000  0.0000
# 342739     0  HGDP01248     0  HGDP01376  OT   0  1.0000  0.0  0.0000  0.0000
# 342740     0  HGDP01248     0  HGDP00671  OT   0  1.0000  0.0  0.0000  0.0000
# 342741     0  HGDP01248     0  HGDP01024  OT   0  0.8632  0.0  0.1368  0.1368
#
# ...

# %%
reduced
# Out:
#         PHATE1    PHATE2         ID
# 0    -0.022661 -0.022885  HGDP00448
# 1    -0.022980 -0.022971  HGDP00479
# 2    -0.022321 -0.022851  HGDP00985
# 3    -0.022368 -0.022693  HGDP01094
# 4    -0.014651 -0.015931  HGDP00982
# ...        ...       ...        ...
# 1038 -0.013425  0.023400  HGDP00953
# 1039  0.010440 -0.018361  HGDP01070
# 1040  0.008513 -0.021476  HGDP01376
# 1041  0.008962 -0.018471  HGDP00671
# 1042 -0.035390  0.018579  HGDP01024
#
# [1043 rows x 3 columns]

# %%
reduced["ID"]
# Out:
# 0       HGDP00448
# 1       HGDP00479
# 2       HGDP00985
# 3       HGDP01094
# 4       HGDP00982
#           ...
# 1038    HGDP00953
# 1039    HGDP01070
# 1040    HGDP01376
# 1041    HGDP00671
# 1042    HGDP01024
# Name: ID, Length: 1043, dtype: object

# %%
relatedness_to_daddy["ID"]
# Out:
# 407       HGDP00448
# 1448      HGDP00479
# 2488      HGDP00985
# 3527      HGDP01094
# 4565      HGDP00982
#             ...
# 342737    HGDP00953
# 342738    HGDP01070
# 342739    HGDP01376
# 342740    HGDP00671
# 342741    HGDP01024
# Name: ID, Length: 1042, dtype: object

# %%
df
# Out:
#            FID1       IID1  FID2       IID2  RT  EZ   Z0   Z1   Z2  PI_HAT  \
# ID
# HGDP00001     0  HGDP00001     0  HGDP01248  OT   0  1.0  0.0  0.0     0.0
# HGDP00003     0  HGDP01248     0  HGDP00003  OT   0  1.0  0.0  0.0     0.0
# HGDP00005     0  HGDP00005     0  HGDP01248  OT   0  1.0  0.0  0.0     0.0
# HGDP00007     0  HGDP00007     0  HGDP01248  OT   0  1.0  0.0  0.0     0.0
# HGDP00009     0  HGDP00009     0  HGDP01248  OT   0  1.0  0.0  0.0     0.0
# ...         ...        ...   ...        ...  ..  ..  ...  ...  ...     ...
# HGDP01415     0  HGDP01415     0  HGDP01248  OT   0  1.0  0.0  0.0     0.0
# HGDP01416     0  HGDP01416     0  HGDP01248  OT   0  1.0  0.0  0.0     0.0
# HGDP01417     0  HGDP01248     0  HGDP01417  OT   0  1.0  0.0  0.0     0.0
# HGDP01418     0  HGDP01418     0  HGDP01248  OT   0  1.0  0.0  0.0     0.0
# HGDP01419     0  HGDP01248     0  HGDP01419  OT   0  1.0  0.0  0.0     0.0
#
# ...

# %%
df["PI_HAT"].unique()
# Out:
# array([0.    , 0.0784, 0.0656, 0.0728, 0.0838, 0.0861, 0.0715, 0.0766,
#        0.0655, 0.0884, 0.1311, 0.1189, 0.1271, 0.1112, 0.1127, 0.1095,
#        0.1175, 0.1124, 0.1102, 0.1148, 0.1119, 0.1181, 0.1309, 0.1337,
#        0.1277, 0.1329, 0.1303, 0.131 , 0.1313, 0.1306, 0.1308, 0.1324,
#        0.1377, 0.1338, 0.136 , 0.1353, 0.1393, 0.128 , 0.1386, 0.1332,
#        0.1363, 0.1282, 0.1366, 0.1349, 0.139 , 0.1346, 0.1267, 0.1317,
#        0.1312, 0.1388, 0.1314, 0.1264, 0.1265, 0.1283, 0.1323, 0.1376,
#        0.1336, 0.1344, 0.1367, 0.1291, 0.1281, 0.1342, 0.1261, 0.12  ,
#        0.1207, 0.1132, 0.1163, 0.0875, 0.1147, 0.1196, 0.1199, 0.0815,
#        0.1278, 0.1229, 0.1214, 0.1144, 0.1241, 0.1205, 0.1255, 0.1172,
#        0.1244, 0.1176, 0.1187, 0.114 , 0.1054, 0.1269, 0.1307, 0.1331,
#        0.1268, 0.1276, 0.1299, 0.1368, 0.1319, 0.1348, 0.1318, 0.1304,
#        0.1245, 0.1296, 0.1262, 0.1247, 0.1294, 0.1249, 0.1356, 0.125 ,
# ...

# %%
bed
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_15597/2502319264.py in <module>
# ----> 1 bed
#
# NameError: name 'bed' is not defined

# %%
import plotly.express as px

fig = px.scatter(df.query("PI_HAT > 0.06"), x="PHATE1", y="PHATE2", 
           color="DST", width=600, height=600, hover_name=df.query("PI_HAT > 0.06").index)

fig

# %%
import plotly.express as px

fig = px.scatter(df.query("PI_HAT > 0.06"), x="PHATE1", y="PHATE2", 
           color="DST", width=600, height=600, hover_name=df.query("PI_HAT > 0.06").index)

fig

# %%
from bed_reader import open_bed
plt.hist(open_bed("/home/shussain/popviz/genomic_data/hgdp_QC_IMP.bed").read().ravel())
# Out:
# (array([4.05915787e+08, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 1.89446165e+08, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 6.34323100e+07]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ],
#        dtype=float32),
#  <BarContainer object of 10 artists>)

# %%
euc = np.load("/home/shussain/popviz/experiments/cetroid/pw_euc_dist.npy")
euc_daddy = euc[408, :]
euc_daddy
# Out:
# array([734.8102 , 736.1454 , 736.36945, ..., 681.0286 , 682.19794,
#        599.00336], dtype=float32)

# %%
o = np.zeros(1043)
o[408] = 1

o = o == 0

# %%
o
# Out:
# array([False, False, False, ..., False, False, False])

# %%
import plotly.express as px

fig = px.scatter(x=reduced["PHATE1"][o], y=reduced["PHATE2"][o], 
           color=euc_daddy[o], width=600, height=600, hover_name=pops["pop_group"][o])

fig
