# %%
import numpy as np
import pandas as pd
from phate import PHATE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dist = np.loadtxt('distance_matrix')
plt.imshow(dist, vmin=1700)

# %%
ph = PHATE()
emb = ph.fit_transform(dist)
# Out:
# Calculating PHATE...
#   Running PHATE on 2504 observations and 2504 variables.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.96 seconds.
#     Calculating KNN search...
#     Calculated KNN search in 0.42 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.06 seconds.
#   Calculated graph and diffusion operator in 1.46 seconds.
#   Calculating landmark operator...
#     Calculating SVD...
#     Calculated SVD in 0.32 seconds.
#     Calculating KMeans...
#     Calculated KMeans in 23.10 seconds.
#   Calculated landmark operator in 25.65 seconds.
#   Calculating optimal t...
#     Automatically selected t = 39
#   Calculated optimal t in 3.99 seconds.
#   Calculating diffusion potential...
#   Calculated diffusion potential in 0.82 seconds.
#   Calculating metric MDS...
#   Calculated metric MDS in 10.68 seconds.
# Calculated PHATE in 42.62 seconds.

# %%
sns.scatterplot(x=emb[:, 0], y=emb[:, 1])
# Out:
# <AxesSubplot:>
